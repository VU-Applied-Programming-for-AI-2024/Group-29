# %%
import os
import requests

def fetch_live_fixtures():
    url = "https://api-football-v1.p.rapidapi.com/v2/fixtures/live"
    headers = {
        'X-RapidAPI-Key': 'd2e9c50e71msh9c1aa43d831af5cp1b4350jsnd108d9d34ba6',
        'X-RapidAPI-Host': 'api-football-v1.p.rapidapi.com'
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for bad responses (4xx or 5xx)

        data = response.json()  # Parse JSON response
        print(data)  # Print the fetched information

    except requests.exceptions.RequestException as e:
        print(f"Error fetching live fixtures: {e}")

# Example usage:
fetch_live_fixtures()
# Out:
# {'api': {'results': 63, 'fixtures': [{'fixture_id': 1202928, 'league_id': 6165, 'league': {'name': 'Cup', 'country': 'Latvia', 'logo': 'https://media.api-sports.io/football/leagues/658.png', 'flag': 'https://media.api-sports.io/flags/lv.svg'}, 'event_date': '2024-06-22T11:00:00+00:00', 'event_timestamp': 1719054000, 'firstHalfStart': 1719054000, 'secondHalfStart': 1719057600, 'round': 'Play-off Round', 'status': 'Extra Time', 'statusShort': 'ET', 'elapsed': 119, 'venue': 'Baldones Stadions', 'referee': None, 'homeTeam': {'team_id': 18962, 'team_name': 'Ķekava / Auda', 'logo': 'https://media.api-sports.io/football/teams/18962.png'}, 'awayTeam': {'team_id': 4139, 'team_name': 'JDFS Alberts', 'logo': 'https://media.api-sports.io/football/teams/4139.png'}, 'goalsHomeTeam': 2, 'goalsAwayTeam': 3, 'score': {'halftime': '0-2', 'fulltime': '2-2', 'extratime': '0-1', 'penalty': None}, 'events': [{'elapsed': 21, 'elapsed_plus': None, 'team_id': 4139, 'teamName': 'JDFS Alberts', 'player_id': 72565, 'player': 'M. Zegele', 'assist_id': None, 'assist': None, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'elapsed': 26, 'elapsed_plus': None, 'team_id': 4139, 'teamName': 'JDFS Alberts', 'player_id': None, 'player': 'K. O. Augusts', 'assist_id': None, 'assist': None, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'elapsed': 62, 'elapsed_plus': None, 'team_id': 18962, 'teamName': 'Ķekava / Auda', 'player_id': None, 'player': 'N. R. Kiala', 'assist_id': None, 'assist': None, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'elapsed': 67, 'elapsed_plus': None, 'team_id': 18962, 'teamName': 'Ķekava / Auda', 'player_id': None, 'player': 'N. R. Kiala', 'assist_id': None, 'assist': None, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}, {'elapsed': 90, 'elapsed_plus': 5, 'team_id': 4139, 'teamName': 'JDFS Alberts', 'player_id': None, 'player': 'R. Guliaks', 'assist_id': None, 'assist': None, 'type': 'Card', 'detail': 'Red Card', 'comments': None}, {'elapsed': 94, 'elapsed_plus': None, 'team_id': 4139, 'teamName': 'JDFS Alberts', 'player_id': None, 'player': 'R. Aditajs', 'assist_id': None, 'assist': None, 'type': 'Goal', 'detail': 'Normal Goal', 'comments': None}]}, {'fixture_id': 1191218, 'league_id': 6131, 'league': {'name': '2. Division - Group 2', 'country': 'Norway', 'logo': 'https://media.api-sports.io/football/leagues/474.png', 'flag': 'https://media.api-sports.io/flags/no.svg'}, 'event_date': '2024-06-22T11:30:00+00:00', 'event_timestamp': 1719055800, 'firstHalfStart': 1719055800, 'secondHalfStart': 1719059400, 'round': 'Group 2 - 12', 'status': 'Second Half', 'statusShort': '2H', 'elapsed': 90, 'venue': 'MUS Stadion Sandskogan', 'referee': None, 'homeTeam': {'team_id': 7033, 'team_name': 'Stjørdals-Blink', 'logo': 'https://media.api-sports.io/football/teams/7033.png'}, 'awayTeam': {'team_id': 2239, 'team_name': 'Skeid', 'logo': 'https://media.api-sports.io/football/teams/2239.png'}, 'goalsHomeTeam': 0, 'goalsAwayTeam': 0, 'score': {'halftime': '0-0', 'fulltime': None, 'extratime': None, 'penalty': None}, 'events': [{'elapsed': 16, 'elapsed_plus': None, 'team_id': 2239, 'teamName': 'Skeid', 'player_id': None, 'player': 'K. Ghaedamini', 'assist_id': None, 'assist': None, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'elapsed': 32, 'elapsed_plus': None, 'team_id': 7033, 'teamName': 'Stjørdals-Blink', 'player_id': None, 'player': 'F. Vinje', 'assist_id': None, 'assist': None, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'elapsed': 36, 'elapsed_plus': None, 'team_id': 2239, 'teamName': 'Skeid', 'player_id': 57349, 'player': 'H. Yusuf', 'assist_id': None, 'assist': None, 'type': 'Card', 'detail': 'Yellow Card', 'comments': None}, {'elapsed': 43, 'elapsed_plus': None, 'team_id': 2239, 'teamName': 'Skeid', 'player_id': None, 'player': 'L. Hoyland', 'assist_id': None, 'assist': None, 'type': 'Card', 'detail': 'Yellow Card', 'comments': 'misses next match'}, {'elapsed': 5 ...
